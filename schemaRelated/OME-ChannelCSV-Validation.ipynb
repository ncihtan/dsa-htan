# %% [markdown]
# #  DSA Schema basic example (Masoud)
#
# This notebook allows you to test a basic schema for the ome csv files in use with DSA servers.
#
# The csv has **6** columns besides the csv default index one.
# The csv converted to JSON file to test with the designed schema.
#
# ---
#
# ## Contents
#
# 1. [Lib Setup](#Lib-Setup)
#
# 1. [CSV Download from DSA](#CSV-Download)
#     1. [Read CSV File](#CSV-Read)
#     1. [Convert to JSON](#CSV-to-JSON)
# 1. [OME-Schema](#OME-Schema)
#     1. [Validate JSON File](#JSON-Validation)

# %% [markdown]
# ## Setup <a class="anchor" id= "Lib-Setup"></a>

# %%
import girder_client
import os,sys
import pandas as pd
import numpy as np
import json
import csv
import sys
import getpass
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

! pip install jsonschema    
from jsonschema import validate  
# !pip install emoji --upgrade
import emoji
# Out:
# Requirement already satisfied: jsonschema in /home/mohamed/anaconda2/lib/python2.7/site-packages (2.6.0)
# Requirement already satisfied: functools32 in /home/mohamed/anaconda2/lib/python2.7/site-packages (from jsonschema) (3.2.3.post2)
# Requirement already up-to-date: emoji in /home/mohamed/anaconda2/lib/python2.7/site-packages (0.6.0)

# %% [markdown]
# ## CSV file download <a class="anchor" id= "CSV-Download"></a>

# %%
csv_file_id = "5f3d8b53c0ac4ed1ea110f9b"
request_url = "item/" + csv_file_id + "/download?contentDisposition=attachment"
base_url = "https://styx.neurology.emory.edu/girder/api/v1/"
gc = girder_client.GirderClient(apiUrl = base_url)
gc.authenticate(username=None, password=None, interactive=True, apiKey=None)
csvfile = gc.get( request_url, jsonResp=False)
# Out:
# Login or email: masoud
# Password for masoud: ········

# %% [markdown]
# ## CSV Read <a class="anchor" id= "CSV-Read"></a>

# %%
raw_data = StringIO(csvfile.content)
df = pd.read_csv(raw_data)
df
# Out:
#     channel_number  cycle_number      marker_name          label  \
# 0                0             0            DNA 1  Hoechst 33342
# 1                1             0  A488 background           none
# 2                2             0  A555 background           none
# 3                3             0  A647 background           none
# 4                4             1            DNA 2  Hoechst 33342
# 5                5             1  A488 background      Alexa 488
# 6                6             1  A555 background      Alexa 555
# 7                7             1  A647 background      Alexa 647
# 8                8             2            DNA 3  Hoechst 33342
# 9                9             2  A488 background      Alexa 488
# 10              10             2             LAG3      Alexa 555
# 11              11             2           ARL13B      Alexa 647
# 12              12             3            DNA 4  Hoechst 33342
# 13              13             3             KI67      Alexa 488
# 14              14             3          KERATIN      Alexa 555
# 15              15             3              PD1      Alexa 647
# 16              16             4            DNA 5  Hoechst 33342
# 17              17             4           CD45RB      Alexa 488
# 18              18             4             CD3D      Alexa 555
# 19              19             4             PDL1      Alexa 647
# 20              20             5            DNA 6  Hoechst 33342
# 21              21             5              CD4      Alexa 488
# 22              22             5             CD45      Alexa 555
# 23              23             5             CD8A      Alexa 647
# 24              24             6            DNA 7  Hoechst 33342
# 25              25             6            CD163      Alexa 488
# 26              26             6             CD68      Alexa 555
# 27              27             6             CD14      Alexa 647
# 28              28             7            DNA 8  Hoechst 33342
# 29              29             7            CD11B      Alexa 488
# 30              30             7            FOXP3      Alexa 555
# 31              31             7             CD21      Alexa 647
# 32              32             8            DNA 9  Hoechst 33342
# 33              33             8             IBA1      Alexa 488
# 34              34             8             ASMA      Alexa 555
# 35              35             8             CD20      Alexa 647
# 36              36             9           DNA 10  Hoechst 33342
# 37              37             9             CD19      Alexa 488
# 38              38             9             GFAP      Alexa 555
# 39              39             9         GTUBULIN      Alexa 647
# 40              40            10           DNA 11  Hoechst 33342
# 41              41            10          LAMINAC      Alexa 488
# 42              42            10            BANF1      Alexa 555
# 43              43            10           LAMINB      Alexa 647
#
#     excitation_wavelength  emission_wavelength
# 0                     395                  431
# 1                     485                  525
# 2                     555                  590
# 3                     640                  690
# 4                     395                  431
# 5                     485                  525
# 6                     555                  590
# 7                     640                  690
# 8                     395                  431
# 9                     485                  525
# 10                    555                  590
# 11                    640                  690
# 12                    395                  431
# 13                    485                  525
# 14                    555                  590
# 15                    640                  690
# 16                    395                  431
# 17                    485                  525
# 18                    555                  590
# 19                    640                  690
# 20                    395                  431
# 21                    485                  525
# 22                    555                  590
# 23                    640                  690
# 24                    395                  431
# 25                    485                  525
# 26                    555                  590
# 27                    640                  690
# 28                    395                  431
# 29                    485                  525
# 30                    555                  590
# 31                    640                  690
# 32                    395                  431
# 33                    485                  525
# 34                    555                  590
# 35                    640                  690
# 36                    395                  431
# 37                    485                  525
# 38                    555                  590
# 39                    640                  690
# 40                    395                  431
# 41                    485                  525
# 42                    555                  590
# 43                    640                  690

# %% [markdown]
# ## Convert to JSON <a class="anchor" id= "CSV-to-JSON"></a>

# %%
result = df.to_json(orient="records")
jsonFile = json.loads(result)
jsonFile[0]
# Out:
# {u'channel_number': 0,
#  u'cycle_number': 0,
#  u'emission_wavelength': 431,
#  u'excitation_wavelength': 395,
#  u'label': u'Hoechst 33342',
#  u'marker_name': u'DNA 1'}

# %% [markdown]
# ## OME Schema <a class="anchor" id= "OME-Schema"></a>

# %%
ome_schema = {
    "$schema": "http://json-schema.org/draft-07/schema",
    "$id": "http://example.com/example.json",
    "type": "object",
    "title": "The root schema",
    "description": "The root schema comprises the entire JSON document.",
    "default": {},
    "examples": [
        {
            "channel_number": "0",
            "cycle_number": "0",
            "emission_wavelength": "431",
            "excitation_wavelength": "395",
            "label": "Hoechst 33342",
            "marker_name": "DNA 1",
        }
    ],
    "required": [
        "channel_number",
        "cycle_number",
        "emission_wavelength",
        "excitation_wavelength",
        "label",
        "marker_name",

    ],
    "properties": {
        "channel_number": {
            "$id": "#/properties/channel_number",
            "type": "number",
            "title": "The channel_number schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "0"
            ]
        },
        "cycle_number": {
            "$id": "#/properties/cycle_number",
            "type": "number",
            "title": "The cycle_number schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "0"
            ]
        },
        "emission_wavelength": {
            "$id": "#/properties/Proc_Seq",
            "type": "number",
            "title": "The emission_wavelength schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "431"
            ]
        },
        "excitation_wavelength": {
            "$id": "#/properties/excitation_wavelength",
            "type": "number",
            "title": "The excitation_wavelength schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "395"
            ]
        },
        "label": {
            "$id": "#/properties/label",
            "type": "string",
#             "minLength": "2",
#             "pattern": "[^#?)($]{1,}+ [0-9]{1,}$",
            "pattern": "([A-Z]{1,})|([a-z]{1,})",            
            "title": "The label schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "Hoechst 33342"
            ]
        },
        "marker_name": {
            "$id": "#/properties/marker_name",
            "type": ["number", "string"] ,
#             "minLength": "1",
            "pattern": "([A-Z]{1,})|([a-z]{1,})",
            "title": "The marker_name schema",
            "description": "An explanation about the purpose of this instance.",
            "default": "",
            "examples": [
                "DNA 1"
            ]
        }
    }
}

# %%
#For validation test
#jsonFile[0]["label"] = 5

# %% [markdown]
# ## Validate JSON File <a class="anchor" id= "JSON-Validation"></a>

# %%
not_valid_entry = 0
for idx, entry in enumerate(jsonFile):
    try:
     validate(instance = entry, schema = ome_schema)
    except :
      print("Not valid record index", idx)
      not_valid_entry += 1
#     else:
#       print(idx, " valid record")   

if not_valid_entry:
       print(emoji.emojize('Final result file is not valid :thumbs_down:'))
else:
       print(emoji.emojize('Final result file is valid :thumbs_up:'))
# Out:
# Final result file is valid 👍

# %%
# %%javascript
# Jupyter.notebook.save_checkpoint();
# Jupyter.notebook.session.delete();
